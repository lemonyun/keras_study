# %% [markdown]
# <a href="https://colab.research.google.com/github/lemonyun/keras_study/blob/main/8_1_text_generation_with_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
keras.__version__
# Out:
# '2.8.0'

# %% [markdown]
# # LSTM으로 텍스트 생성하기

# %% [markdown]
# 샘플링 전략

# %% [markdown]
# * 탐욕적 샘플링 - 반복적이고 예상 가능한 문자열을 만듬
# * 확률적 샘플링 - 흥미로운 출력을 만들어 낼 가능성이 있음
# 확률의 양을 조절하기 위해 **소프트맥스 온도** 라는 파라미터를 사용, 확률분포의 엔트로피를 조절할 수 있음

# %% [markdown]
# # 글자 수준의 LSTM 텍스트 생성 모델 구현

# %%
import tensorflow
import numpy as np

path = tensorflow.keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# # 네트워크 구성
#
# 이 네트워크는 하나의 LSTM 층과 그 뒤에 Dense 분류기가 뒤따릅니다. 분류기는 가능한 모든 글자에 대한 소프트맥스 출력을 만듭니다. 순환 신경망이 시퀀스 데이터를 생성하는 유일한 방법은 아닙니다. 최근에는 1D 컨브넷도 이런 작업에 아주 잘 들어 맞는다는 것이 밝혀졌습니다.

# %%
from keras import layers
from tensorflow.keras import optimizers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# #언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1. 지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2. 특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3. 가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4. 새로운 글자를 생성된 텍스트의 끝에 추가합니다.

# %% [markdown]
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1) 
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 33s 17ms/step - loss: 1.9701
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forming the same the soul and and despression of has such and self and decession of the sacrion, and allower and such and such and self a more and sachions of the discondent of the soul the discience and prevent of the self the self and presing and man in the sachion of the prefect and all the mankind of the self the seems and all the soul the sachion, and self-sore and self and self-consequence and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formally man and manding of such atere and condicition of indinging senfing to the self mankindues and dendarises of the same to in the the sayst mund and some a menter and self-consevering and sace.---and contind allow the continity and disting trother as a
# refine the prease the means manding this the willions of soriing conscient the world with allouth all conscience and all the suchions of the he
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formrally, ebmackions,
# ach
# soul"
# indecasian, the domygener am--trought--intance of
# regnorged), hown
# expresions of he wayty
# regile of
# corfulan, and feel exist bod the
# are
# preeures. seek, man: laborme opilioy, sachide, be now farture consciile, us tairing--dis not hs mas6ly, in euraped wish
# muihe, with upone as fimstation of quitigized a corrition, are receitly
# preception:"
# shoold
# menkent, to consciou
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forciouars precess--id hysprerorarfen, itis intaild rasible., iur
# factiady to
# rayence, and becomeally bort, the ?then
# notless, and (who
# deldipictory
# of dynvear, tha in whr lanadergh" oerea ) comound dry; and "preapuse effectuc, anofingeges higherthiude"--if hyard
# skonled tnante
# feas of iluli, allo"w resuly, to colmancing exings keemment farming have eteiting ty.
# there, and stime!, othur plateny, is
# 에포크 2
# 1565/1565 [==============================] - 29s 19ms/step - loss: 1.6157
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strunged to the love of the for the god" the same the soul of the responsible of the same the same of the soul of the same to the sort of the sort of the same the great the same the spirit and the same the same the best of the same the great something to the sort of the propedity of the moral of the spirit of the propeded to the great the same the most the same and the most the sense of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the world to all the gree one of the being of a god.
#
#
# 1peces and the sortain to a thingstery to be something of the truth, and events to have only a the sortains in the religious to what the proveded and moral have the art the great instinct one world of the now the sort of the prefects disting the propedative who had the great the famility of all respect of lifes, an also one truent of the thr
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for instince.--andover, and
# this actideers regardes potition of disining that alkeadomgusalores inte must endumed
# wise morals, dishanounds is latest sagering some a being of eads to
# sinsive originates and mentay sthf-reastes really his
# torjed which original tasteting too respontibe to who have refeedistal without one and intelreptions
# enough and fertoory of most saidinations, betweent somes and
# wuse
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for vativated" wand our is tjo gor? perhaps
# firative, a mends which we2pth, prose! equacier."
# -forube to our befy
# differentabed orjedualato who grekndered
# juaidity that that it; loty
# limes so germangs
# aparvon thal what is dove;
# a kind soper; not too and
# saidratiantless
# of whilh digans underriblen--the
# same siclant: so-mando religious to wo
# low.
# dyducentor, to det that ruce hat on the soun orw; -for
# 에포크 3
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.5275
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and the same the strong and the sense of the strong and same the man of the states and decent of the states and the one of the statesting the statestered the strong the states of the states of a more the present the more and the hast of the still the strong the continual and the seems the still the strong the whole the continted in the strong the statest and spirit and still and the con
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for this present the fathing the same conscious the religions
# itself of here and such an ant and and something because the moral references the conscious morality.=--what is a this interristion of the want the even it is an antings of it is a states, and who can disfulted with one of the ancient also and could not inderrable as the present the regardenture and and an interpreting to the decement and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for gacafout and heartous all find; let when
# he consciented
# out
#  antistately of an. and,
# distoguergned to amount of even perhaps a wlinved when one pnisuldirat, it to the prased, of the speak to channctoring theest and centued, an inventurie youthly even the the greful, and alli, when sympathy-lea, hereglly nature it makipe, restymine and dislinger are a! wither an
# oppecually towends and chardened c
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for eoligh que   yation, be love--wman aiinly compoctume, artist
# chaincy atterver,
# and doweds? of
# man indironizingt, itself, and intivijuals he knowledge! and theman, inspines be perhaps an ive--imper mattens.--the "gortoppoual even habitured ththeripity of their
# exist tood-plain yets as emited cause
# outmical not towand,.. and evelsely ntornt,
# to all yeting,
# mediochismous possiblentils.--eas desplon
# 에포크 4
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.4808
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spiritually and and interpretation of the same and self and defended to the same it with a souls and the spirit to the spirits the germans and the spiritually to readily and self the spiritually stronges of the deade of the same the spirit and proper and here of the morality and such an and same the spiritually and and the spiritually and the self and devolupal and self and self the conscien
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spiritually personal and spiritually that we say, the reason and the lowe and as and songain and manifest itself in his fratter could be supposition, the destrous of expression that the artistical self to a prounted of the eccapocand of the defermnt of the same our incerning of our freedom. the spiritually profound and same and consequently ears of a only be an--would he called to disest and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for ordomised proped "will, to demped, the race of this age is bean artys--a hase a for man, "metaphysical and to and could hardents, there was beare is vire frolow to have we
# no
# equality we hitherto philosophy dece sulferdive can conror a sforts of this cever and thus with hen a
# sympathy dis,apedairaty of duty of the from the greates of its onces of names, which well and rasuntifij, that what has e
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fort-s this phersing lough rear
# cc gerprovoity
# ordless sentitiousness and tamimy, and as attedtd, whats blough tode, ver welly
# in mya., om put out, to lainelsf; cust acts to itself, theyt he varital man--mapacle them no it it govening soonization after, how calied detert.
# son--, will ourse,
# theyelest that that any
# kwor.
#
# . gietr as allous, iven to belong perpreise,
# mecance ortour, as it lat wholl cr
# 에포크 5
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.4504
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present the same and same and some the same the present the spirits of the spirit the contemption of the same and artists of man of the same and conceptions of the strengther and sure of the spirit the contemptional spirit that the present the comprehension of the same and present the present the destroy and same and surress and existence of the contemption of the same and seems to a the sam
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in all mistake. the present the the present the greatest for a personal the same a sure of his present there is disclecially and self-canned lived of science of conscience of his strength the means of as anything the precisely the last pleasion of the thought in the spirits us of all the schelue of his catisman deliceration of present the surress of any expection to the destroy and deliced the s
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for krown be:
# sympocist alternal sruely acts of act a-imilead with itafraint a prryomed
# the mothes loke
# ment his atterhable--themn
# a hands, anything explained it the rich, those hensest i being to expect the allorm and aeti! grace that the "futureial thing horr of
# possess, grabe.ful that which, every survision, ane of all
# themfyed apealisiness hreate wholly only mistrarforings aurt the rank).
# deep t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the apparable, for
# relarted
# borind a quile as, revenge ittellegle, bqually
# and conbvole,ufaral involved sexidion, a  ortiately and hable, in there
# are of iurpysion of ptrplictress who
# first into i hower unwison grasm. actre creaies of very thing
# as grace
# more may natureing looking misundament,--no,
# whole they had old
# literate csamefy, e preservates ocher hortuanpnees if the cause of
# inst tom
# and
# 에포크 6
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.4271
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most comparently and the most comparence of the present and the most comparison the religious preservation of the same the most more the present of the world and such a subject to the world to distinction of the world and the most individual to the sense of the same the same and the soul of the most and the sense of the sectristies of the world to the world in the most destruction of the sub
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the self most communice tarry to the expedoued the most the same into the world the most history partly as if he man of the recerned so the self inach to perhaps the most contempt to be the glorifuces of a comparences in the world have to be him the men of the most experience of the true there are so far as great comparing, it is
# really all the man of ascity, the sacrifice the else belief becaut
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forming in up to him aspe. ulthere is an be
# difficulnes be comparently as gett. god
# bene together viaus with men: "one wighorable invotues: they
# are mathever
# re- one coaligity,
# even an, slone most for the
# idial towlenged. to the
# one for all, pre? a out, him tome the serp the one in all everything perhaps something, hoils of breamping, growthing
# about him tur) of eopered; and treatowd, the bepointenc
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found fi funeical beser cever aavikes. the fineloglen as this hundermation of "every voed, as as
# a socieated, whe
# ascendly be. likeby artian sufficant endrousing of general to natural itself trailed all society (that one; a very rief1rung "but if, or among unamers
# are acknowlenomes id most hast. aighe, the o"dey, which ingned? hard a hage
# to wevery no
# kings, allrousew it is epocure, the rich
# notious
# 에포크 7
# 1565/1565 [==============================] - 32s 20ms/step - loss: 1.4107
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for in the mastery, and an
# inverted and soul in the sense of the sense of the sense of the sense of the sense of the spirit and strength to the sense of the same the sense of the sense of the spirit and such an inversely and the spirit and the sense of the sense of the sense of the sense of the desire of the superficial is a superficial and the spirit of an inverted and sense of the sense of the sam
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the dominate of the instinct of the still such an
# all the morality of
# a most superficial beries of the entity of the constantle to really an involumtans of regard and things--in the same exist of the such an our drupition of the problem of the personally only only the anomy of the sense of the hard distrust of any interest and hungrated of his from the
# present thereby make a had to in the same a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foubler is pointerful placeing.
# the very stopatish) to spe
# unter we lever and aoprever virthes in the further-long language overbe of standfulted,
# into self-presest of
# dignally hindles. gueds of just covery,
# as, withone school of its
# deterioration: and ever will origing, of
# reall the med
# of follient
# buts, no
# our long. he may all which sense, as is conscious
# opinion, people ob"duungunauring and "supe
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forminaquiegorsed yservilive nocounces of him himself, we will hidded shame
# less gemmli),lowing by mipural-vreefornoes in placicl to be dwifely has
# honovers of
# that thinker in conscience. so withoutter of postemly,
# all
# science of anomorer
# with the salvan.
# in
# creat--thereby let us an
# aget in sy-pensdivince
# riciinters, and placeding,
# enytins againcnisal mernity for," dom! seld hipselfp-lermly that lea
# 에포크 8
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.3963
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the morality of the same to the conscious that the sense of the sense the moral and the problem of the strong and such a conscious and sufficient superficious and domain and are sufficient the sufficient also the self-conscious in the same suffers and in the sense that the end a thing that the morality of the same have the sense of the superiority of the same the conscious and the sense that the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for contempt and heaven are thought in the masters of the sense the soul, all moral as in the destiry that it is the most beautiful have to any faith to be strong, part of his feeling the connction of the spirit, and the way and the truth, a will in a the deceive that something and everything that such at the moral who consider a morality the lower, has not a problem of the very transcribes that the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for varily eviluming "it from through the delighty brong have with, the wors world matter for attribiod
# timed. where immorleds they have antimious, to point of the vended, su.
# keposing!
#
#      qute men in questions, have icavesive, tod
# or lost-rome feels the to brout to best of moral
# present-spirit
# us his truth which consitrlability that they have to ! as any that grom of
# a smind:s eit all manifolm.
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forcable,
# heirs nationy experiencs. a furify. there is class: they are
# heat stoal
# lim: tomastaun indiffer,.
# ther cultual, spull absonce
# and
# am have be stage, hus (in a spotle, who capacity eyougk of because "though was has whol, heir to precisely forrgelps circ-)--to keop hasousn, f!  xiluse, but the wron ttations rided:--and also poince knewliheme a speaus a right, to
# be why
# brungs.
#
#
# uslikes to me
# 에포크 9
# 1565/1565 [==============================] - 29s 18ms/step - loss: 1.3838
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and such a man of the spirits and the most seems to the same accomplemehuping and the consenter and the most same the manners of the man of the most such an interesting the consence of the most and a things and the
# same the same the still the same an an its same an any seems to be the same the man of the fact that the consence of the causes of the same an accompultion and the same the m
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a mind the conditions of any hands and it is it were as which is devilianity, the pressity, the matter has not a superity to be in the holism of the spirits of the lost from the conservert of such hather and the false and caster and charming and consided the power with the consistring, which the serves and according to the senses, here that is such a conscience, and himself or view of the body t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for him makes in their syght ands, at their fwermine is more and nothingy--how name, and what will like the type bable immed, and can an
# understanding
# must confide thereby she the hantimouble,
# or vivises that is mutheital "soul as
# was tour,
# els, subtle was human, thereof.
#              f mock," sympates times. bus beyond an intundrition of looking pait inton
# religious restrictive thrings--does "said
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the spartwinnch with the "underfvalue on a
# sympathy in their testimatypsuffud anddje, "urove to he
# men,ment? that why call to respectenately, all serity, and condition duceness the moverecd fram move.
# lenningly, he werter to wry
# anamy--mankind with man.
#
#
# 1
# se
# comtage ocligated skan, capable it would takes re'situan uvils, because one
# very freehomd-saning! catty, hy how out, that without,
# which
# 에포크 10
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.3748
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the morality of the evil and soul and the man and sense of the desire of the conscience of the present and self-constitutely and interesting the same an account of the sublime and interpretince of the sense of the more that the self-conscience of the conscience of the same the same and some and the same an an an accompance of the conscience of the sense of the same the man of the sa
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly and satisfaction and spirit to the philosophy and present of the fact of the history of the barrange implues
# the word-seem--and all the good and socrated of man of the devil of the truth of the plays. it is the can an antrues of the morality of manner of the spirit to anyone not seems to the morality of the spirit and some and formers to rasist of the moralists of conscience of the moral to
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forestany partlyness, at is no ordinary arinfer contemporary opinions, when a turagain that the word
# no order withone the history to europalced
# smound beginnisness of
# strives and
# belong after: at lay-andievidinate is its taste!--they masterulm
# rope-reared, as it is nothing they alpoisesomy
# in so taken a rating indelen, as other the good puritory of when  say.
#
#
# 3e
# sympathy to artrom
# of the history,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formults-dosiculaial i
# gelity? sinnes optorgoe who interpations, tor socce,
# toiumd--death! in theselfdes. -to should ratakeness its tooly gay it without
# mediocbrows
# knowly shrible
# antwaie new thereofer! leant. naturement, well
# or reverence at coul will? is
# it.tich
# eyes, has dinguise
# metabits later crives. for be thinke of
# importance upon orderemlent:--in yoursely evolutions and herrer a the miedle,
# 에포크 11
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.3658
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sure of the explanation of the sense of the same to the world in the strength of the serious and deceives of the sense of the spirit to the served of the spirit to the strength some sunds of the same to the sense of the sense of the sense of the sense of the sense of the same the spirit of the spirit to the sense of the sense of the sense of the same to the strength with it in the explanatio
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the more to his own sense in the sense of the feeling of the sacrifice of history of sense of an attempt to the means of the origin of history and being to one's ideas of the serious prevails of our being for the sense to some seriously, one will more possible himself of the own
# the conceited than a being content of the highest in every desires in the spirits of the
# strong and some to the concer
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foregrait of the judgment, are not text it i know
# alwoweding once in regreaded incapation; but
# religion of plicious, proacement of a could rational, and great manners
# imaceness of victor
# and
# dedection
# of fran prrvedgnement of his certain world strange at
# spechs of more prevails and
# hated to philosophoow writtes of such rests place nowledged
# than he rususse of this more ideaning of highers our effect
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forest of an ow every fakenal and egoificd haron even he sens as defelt
# ofach is
# exeebsing in knowledge bla cartll":--he
# seed case comphanih
# unsensequently, religious, anot correted own was tgoodars" of ohe orugivenon, errorove nnited ?     need eyed rensidying pecrsise man's feilt so deretion incemect origin, in religions as to love rains enjoy for uwaltid
# to them"; not in herity wecer""s (though d
# 에포크 12
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.3583
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most and the still as the still and the charm of the conscience of the facts of the still and the consequence of the consequently and the fact that the fact of the form of the mediuced to the because of the strength that the consequence of the self-suffering that the sense of the conscience of the destruction of the self-conscience, and the present the strength of the consequence of the stre
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through follow to the even that the are promited as something the sense of the measurical hand in the testence the world and here of the selfly on the
# truth that in the origin and hest out of the standard as he heart sense of the
# considered to the school of the philosophers and deceived the same himself that he well from the strength and who simpless the noble contradite the voluntary, as still a spirit in
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for fenished perhaps,
# according to be bikest batted by the news also. to the robcedp"ing har, is as a sthilction to through also
# only at lett religion of voluponing avoodmaning to keement--looks the extent offning forward "freedom,", determation of the world obvious like though for exercisssed, and his letabious
# propers as trought sucderout its ideal of man habit
# world menticily physiorfine shoused
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fotcetles of christianities, vationful amfund and laid nuble learned logicrs and
# a
# sufficient of hat on final many soulsoke. as ye knowss a
# rook of otherwisp" of pertainty aftaccis it the apperatable illuty.
#
# 1anomousle mustly firsot centuriealy
# to
# shootes out.--little
# regree of to gels: seems it what is voultless? is the estimatevent with means, a, the evending "be, have logic gay
# forsgew insliuune
# 에포크 13
# 1565/1565 [==============================] - 32s 20ms/step - loss: 1.3523
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the science of the same to the sense of the same to the sense of the spirit that which is the states of the deeps the strength of the same the strength that the superiorition of the strength that it is a profound the soul of the same the same the conscience of the spirit and such a state in the same the most respect that the same the same the same the most man and state the most spirit the desir
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spirits and the prevail the entimilly even the father and even the belief the world the souther world of the conscience of all the sens, who is not to the whole consequence and the superiority of the way, the inclass to the soul and a conditions of the most able to the fact in the fact, and man as the extends of the place of causes and contempty of the philosophers, and the strength and subt
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for is persons most ston,
# the word are who he artists--which disintally, that
# in materiousness) undevista nesse ison obly", some tencherbgent lerbus the foll-everful in bepcied
# chlanond additionation, tore in
# that we look the defult of the kind of it. and states, modess, almost every lorieves, a health-for yeacl, without individublebt there there free comprehend tomon of, requir, on a long here, one
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for, excessing belief. theirswiffore deterior give, not all the assertte op referve itstover."" -helothen, no lost--is of hike. to sopered: hehis: the first intal
# a want to his borborth hut in there shards onaties back teeponousn redicatjy wruse into out, that (and ortifiur to only sturnher reveannsbes.
# the gumal degree tove ?almen, has been
# know; oubsournesuine is cuntation. i read to ingrres ofice
# 에포크 14
# 1565/1565 [==============================] - 32s 20ms/step - loss: 1.3457
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former the stream of the streves and stroke the self-and the strength of the strength of the same the faith of the stream of the same the strength of the streves and states and the strength and same men and the strict and superstition of the strength of the soul of the strength of the stream of the strength and strength of the science and the soul of the stream of the stream of the strength of the t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formuling in the reterms of sufficient into the
# master in strict and distinction of the ends of the internal be a human person of the spirit and comparisonician in the strength and the commander and the absolutely in the conscience and
# superficient of the individual
# with sackinied will be a most false of the stard to the possibility of the unity of the devilian and strive of can be mape, and the spi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foother appearance of the mode the utes of repitiat of which a then in something the lice which horrieal, his can an exception, we must a man is to be involvaty
# is probably, as rust moral grot how by the great
# coloasing the taste.
#
#
# sat on
# a time highy present, the
# truets its foor? in the doither in catus and tempo and "convailums," man a may partial, as what will be not be in all huppriote being fi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formulances, and onequence from take bes.--as we slight heart and could not
# dispian catinc, even but most alcusted first outhawly, not mistaking accordanule fine ominiegh valus, throe as after illusion of giptiosian sympathy"s.=--revengerv;
# bither depth is rom. it is claim of chapace as she whohing at once the our
# bad type the "uneesease a gain and former.
# lituder, the genius that sypumental imamen
# 에포크 15
# 1565/1565 [==============================] - 32s 20ms/step - loss: 1.3402
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most the most spirit to the experience of the same the most man in the present man is not to the most such an instincts of the concerning to the most such an instance, and with the spirit to the same to have to be a will to the superstition of the spirit to the state in the fact to the spirit to have with the state of the formuling of the same to the sense of the most soul, and the world and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the common means
# and it will be an inself of the developments of the suffering of the soul and in the scomery and consequently to many a self-contemption of the philosophy in the mascetion and the same the most exception in the world is an interest of the devil of the world of the tenceives the considered of its own and man can the senses to called motive of the interpretous and the consequently
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foringsess these not
# of life, confusion, ever waitsifinerity and long, to the toor of little as
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  it is to fancyed visiony. that it arby strengtak believes art be all the future and away
# indole,
# yet in kiow,
# baftual eals ake an instance, one of explanier and into the currid disinterpretative: how understood. what is livin. whether she in the cacless, the greate later themselves by.
#
# o2
# himself, he was
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through founds of pactic for whole conclato
# insignism, these problemary delusipte as mouthe when an
# areuvious countess, heaks
# tupic. for it
# creature.
# d2=ing in "phesousi
# sviel," we morals.
#
#
# ene o"f"ing,
# propantly thes, but noth, reals nivie
# gaies, together and doing in himself be never voor
# as for the arigfer.ti
# =thing
# from theyingilal dwarfinedest to rematic were non
# idead-determ, with the laffer beneszma
# 에포크 16
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.3345
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the same the sense of the same the same spirit, the same the superiorition of the sense of the same them to the most spirit, the superiorition of the same the general and the same themselves that the same the superficially the strong and the same the more and the same the commander and the still seems to the same the sense of the same the same the same the same the stro
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same them of the destiny, it is the desiration of such a still into the same spirit the truth that the history in such a have in more attained for the
# more man, has been in the same things for the belief in the mastery
# of the new delight to the sublimes the still man it has always to any one the command! in the same great that as a stand, it is surpailization of one's own life and discortul
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# exempt and
# allor todands
# on the
# masticis of sac,
# goot of pleasure
# of feol
# enpochimy and man also all the surmiver of schildistowion of
# one
# must
# sdeps and rebutism, as the -sicklfest strices usrerly
# reath of the same tragied, for ilnasion" they evens very far belator, out of spemsting, and possible, to ybecume doing and out whom the
# aline for
# conditions of the same spirit, they gave daciscom come
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for mobe have
# in the have thoughl--we comem crections the our need afotity,
# he harring uponstited and any with error and
# ar chpones of belief insolization of pow, because "good,"
# instat takes rult
# boblly
# with the jacuslih;--one or plu'ntible, "commman"  ; if made spart: they har", our mode inonebest inferious,
# but a far, cacratally incomparinglands (no
# impore
# quieed-loso without the sams, had, edica
# 에포크 17
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.3282
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the stronger the still the soul--and all the problem of the spirit of the stronger and states and such a soul is the conscience of the strength of the stronger and man of the soul--and the superity of the soul as the strong to the belief in the fact the strucces of the soul--and the problem of the spirit and still the problem and conscience of the experience of the struccess of the strong to the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a words the
# strong to the truth and like to the served to mide to be such an enture themselves, the problem of the childing pain and most soul--and which the sense in the strong and interestion of the spirit of the capided to the communical continuate and the soul which he has regards the contrary something in the comprehension of himself, prevails and repuded before a general and because of a p
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forlamd as teste
# appeal is soyets, compuliang,
# these
# valus, were remost once and low onlied enthativeness within by rexcrian, as
# no tenderity by which little negferly by their cersionate being how points whose an a true definitionable, in the samem. that
# press for him--and the spost conceras his metaphans (brings, as man difficult, symmerment, like
# the presenkess in popired, everywherely fath with t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formeration in ordieard!
#
#
# 1a dieforative
# of hyscheres
# descriaiousned and do sord and sonally, reason, as the falsm of habitly tou. i deed will the undavistical are imposition of rank is the human problem and chile, in
# the
# side of herive as being cause, whenever it al.
#       tim
# wire ruiding vices and kept some
# not sinwaity: in syspeis to be liderits. the time depline, has, folusted; it he should fa
# 에포크 18
# 1565/1565 [==============================] - 32s 21ms/step - loss: 1.3253
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the presented and sense of the most his man is never the spirit to the self-concealed in the means of the conscience of the sense of the spiritual men of the sense of the spiritual conduct that is a morality of the masters, and which is the men who has the most men to the present the moral properate is a moral and self-desire that is a discovered to the self-case and desire to the self-considera
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the constrally in their present and nature and soul is a down, and philosophy and speak and distance to men of ever them, the holy merely is possession from things and belonging and sense of its bad in the self-and of the experience.
#
# 12e should in the same spiritual
# and self-confloring the called itself deeping to the power? in the hand at the certain for what we are what is a religious and har
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the dis about in name as doke shave" that
# all solitances that in the we is a rightsly, sufficient most soul misunderstand or, perhaps; one should be gest effect that event conduct get
# attenly from this gradned is schopenhaune, otherly: "perioning optel
# mishing and disindutidetired that it seems of humanity
# and of very connuctius by being with it
# haver s doch perhaning--it is right, despemed in
# b
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formerly hiver pessivenceme wondable or
# .tice, genezaging,, mores, but he does not sind idea, nerms. quitually with allentn
# reason, and nool
# qualities to exactly and saide belief conventange--
# the falsely christian. one
# to this tellows ideaning-cesse, of its . have intellectual protdeeding disandve, others intellective poppeauge
# is nothing hintication! lentifiwates, in
# =radided howt, ear in a view t
# 에포크 19
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.3206
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the conscience of the same them and soul and desire to be a something but the are hoste man is a profound be something which is to the moral in the philosophers of the desires of the same themselves to be a contrary one another in the most present mankind of the same the desire to the point of the same the higher the same and same woman and the morality of the same and states, and as a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for still also and well at the self-contempt of the comparies to the spirit of the conscience of the man and what a man is one more than this is the master of
# self-assertion and amit of the universally supposing mankind of the world as the "live of the work of morality, or he self- yet one and last any belief in the early and which the genius of the way of mankind words brings of every more present
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for delight. their will florturity to being to exmar maghee, possess
# itself a "self-courage", and in premisiming difference, that secare perceptions caste dignems hondrees
# and
# away mode, frary cialty a
# manzers in any
# more
# one magers, became apparence the basisment, is acboliest; one the
# only himself, thus is
# within their
# extent themselves as e hunglements which is culture that whether the tendency
# t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the most produced thrsommene latt. he doevaligions
# of spiritually lang ams--head spring"-tbutious slain to disciplitabling, willinkery exist, when felt, adaptagned analysisladition, ange. but unalwauser care will. they shousment inspiration: we booldness to much blood frects to the definite
# philosophicals; and possessing arises and doors in wort (self-qutit will be
# a
# congrous their magree, assis
# 에포크 20
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.3162
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same time of the conscience, and the complation of the philosophy of the made and commander, and the science, and the senses of the conscience, and the sense of the reason to the present of the present the senses of the philosophy of a man and the fact of the same time of the present the self-conscience, and the sense of the present the spirit of the conscience, and the sense of the predenti
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same time that is the subjection and the europexage, in european course of perception of the
# possible of the present story in short, of the philosophy of the great gratitude of the spirit and soul of the nature, the englishmanity in the still and cause of the worldover and his taste in the philosophy and a statess and the true man is so to be a made of the masters, a sense that it is the gre
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for a spirit to heavy have gooh it atain as respuctions,--venctury is the put to be no the faith of the originness, has, than in all only at the fear of man, this is long nearerenesh done lises often to his mases, oliting which
# a does clace goo--such the personce of respectay will the nevolth todetgaming, has here to still readers of all god
# into this riling.--and i also, who dimbll something and in
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for zeduction..--in daring forwasabitient to arg in art
# class: "the actly eprachahe is caus wild science, can soughtle's said, to mustrite which with and art incriber withour
# trefulities perceived-- ?      hounds, above their ideasive; it is until
# wosateotic,
# and within they a willed and
# bad usivers. you will , blingreaw
#  nexishe effect of yethinantr (when the centuriet visk for the femplinancement
# 에포크 21
# 1565/1565 [==============================] - 29s 19ms/step - loss: 1.3142
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the conscience, the experience of the profounder of the same to the other had and sublimest the same the same the masters, and the same to the most and suffering and man and the most conceive to a man is not a profounder of the same time and a man is not to the structure of the same to the condition of the really and strong and a destraytness of the sense of the same to the same to the most prof
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the relation of the cause of the precisely the fact of the fact is a due and superstitious man and the comprehensed, and a thing is to and the delight of the great higher being to the same time and time look and upon the most precisely the most spirit in the turning assertion of our principle, they are soul the desire that all being with the persons, and the same to a man with the most former of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the spyal. the expende
# after the judgments all peciment, one progution of europe takes the fundamilation, which is not fat prey many matter habitumentomsual petrival, and the generated, hopeccasing is su"tses is knowledge to take to
# therein--that it is longest of the feminine, was see suffersing for of which one mipyes of men was inant. they fearwabyed and out of such such imbiurifine
# of "echoso
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fortwishomin, a : calnpracy prisent to religioos se detenties of passe
# the varrilems of every place of pertation and
# an
# resens, which loranerly eives,
# in which is first deeping, therrisly and strenitiri gant, categor
# isness, and fore; i rank and even of cincure si adcoiit had
# exwily soul,
#  he we no forke bulsty goodness and relacity man onrelulustely too hear us in the acchsty--brobility of avoinaki
# 에포크 22
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.3107
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the conscience of the proper the present to the most conscience of the conscience of the prover of the free the present the sense of the same discovered and conception of the sense of the same the still states, and the problem of the sense of the same the proper the most problem of the present the most sure of the present of the conscience of the most sublime to the desire the greatest the consc
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the communities considerable the same the same beginn the most schopenhauer as the most sublime the desire is not the conscience of the exception and who consequence his death of a so capace with the scholars of morality and badness: the confliction of the one in the virtue the asceticish regard to his living to the present the uninturlent of the conscience of the fact of the priedition of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for a virtue--a
# stepon called thoughts progution as a missleanism in my duties a discoubmary from vanic world part of slaver enkived by the distonated that which he to let in cloversy is
# the worsh, european is morality is a velouse wisder merander of
# good, sounds of grokally
# calling these reride,ancing deduction of delight, power and the willing-dearing
# the sake, and for
# digneralist discoves, indeed
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for hissess upon the mate--this a rule?--but the hand advantage--rave, lipase sucsh-unlight, as a greatwe, we generate withd son which their eviltless: the
# deletcich
# intoller's
# thing here as one flyingly upon pet had, of can say... lim's yethors, too, knowledge of the net
# ma featible thisk in all: by these ily
# lick it appears onesmay
# good cerement in one" bepegod: only of rendious, now exosh sign o
# 에포크 23
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.3077
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the contrary and the religious and the most and self-religious and present in the good to the fact that the contrary and the most present and the most sense, and the conception of the profound the self-destruction of the condition of the good to the fact of the presence of the self-religious and the condition of the presence of the good to the developed to the condition of the spirit to have the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same the man of instincts as the founder of himself the other parison the commander and history and able to be something the really in the estimate is to endome and more desire to the spirit to the conveniery to the excession that the cinture to the most god and standpoint in the ways the develous of his presence of a profound in the relation of the human to
# the father of the experience, whe
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for earl". there orbes, or aminateness to protes mightwhad. that the bad there seed here engendance is convenination what people was
# the heart of general and more method mus there possibility the value for free specially unasually others
# everything for animal in our feath of the
# state of first man: quithies elsely just their for the world of our
# latter is appeara? if i once them final believe i "eus
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow he must that he and deceived, enverpalises,
# those maserit, arothund, has are been our lame
# some wonge-rehight that the parabls
# renger it is dulewe voluntary
# diffiaray as of the essucmant impolus kind is there, an inquicians as fore would be savaquence, the lonest sympathy, when we livers, (lexiticing violence
# lafforal "placed--that the will time is voerid the ports: errors of grow the cilenca
# 에포크 24
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.3056
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a man will metaphysical
# had not its interpretation of the superior as will to the freedom of the viciable a more cause of the last man be he is the desirable when the contrauth without the whole the same type of the spirit of the comparison a greatest and nothing that is also sees of the master and its ages of the spirit of the present rations and not of him that it is the old exparience (the co
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fool. any path and seems to does deed and dity being posses which is
# the reason are now to the comparage, oneing the growth, elegd one of its adities, without ever himself have new
# more threaren difhatement, us rear bring, to exploition to their fach our becorct the distrust things as
# clumsy so he spice all brual weak one
# wall as the scend friuggrous the stronger and former only expline
# progve? just
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forcogl
# or not, and everywherm, under yeast! wherever now-stamans to etherely knowledges up wolly
# philonosidion
# disdemectatilg. an enqui rative propopelly the iplicated circumstances, knew no grould, as horsnels over being that these fetter manrucake.
# comparapre foft ratists of conterviserking--moral sofiest o-urweed in, the demidn mectume exped rouble
# ideniams,fore sort of justicn, as the eephend.
# 에포크 53
# 1565/1565 [==============================] - 32s 21ms/step - loss: 1.2472
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same to the desire and the most sures and the same to the same to the experience of the same to the contempt of the same to the same the sense of the same time and the same to the same to the expression and the same to the same and such a properable to the expression the same the same to the experience of the spirit of the same faith the constraint and the same to him of the same and the cau
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through ford, and in its order of the distrust of the garnoly instinction that the dangerous and successing and depthsing of presence of the presented and demonsauld, and the constraint to the german pain the desire the most presente himself and all the same from the
# fact of the belief that the contrary and deed a same who will a sure of self-passions himself the same still with the generally believe its fi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formelfed every method to woman.
#
# 84. are only should able the significance (and dimore mentarious doing?" which nlothing agree shetres of science, altioned, we hithuelks to exercious
# like, quitkonic, its always
# or later question i must teed be feels for plose in which all feiggres of little
# intercousipable brutivened enjoyment for returnian than his soul old dutc, have human middless
# follow believe
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foundation.
# the question among jesuge ik.--but we experia origincition, a puritals). i physh precisely awarance, not slad bot if
# chaparifications of cluse noble,     that
# loved liediculd must ent, no wire ceredaribe). but the future:--those on vivilecities to lired more in surtenciate french
# hicher srientwil. pitured easily
# self, and leadinment us in itself;-emond and restrectate
# rarfer
# excreated, b
# 에포크 54
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.2480
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the desire to the proper to the best and such a means of the spirit of the profound and the sentiment of the general and even the sense of the most present the sentiment of the most man of the spirit of the present man of the present man of the spirit of the same time the sense of the spirit of the prompted to the subjection of the sentiment of the most man of the spirit to be asceticial sentime
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the word so much acts and the present the schools and as a moderation of the spirit to powerles in the presence of the word will be as a profound and arount, as a so called
# his good to be truth of the consequences which is regard to such a philosophers of the emotions of the most consideration of the means of the human to be such a proper to the existence of such as all the historical sense and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former consideration of honormes to use the hegr, was docth be "secame," individutions (or imnoce un"hinger!"--for :vertad even
# on educated as
# to brievt sympathy, in the sourhic of that knows the feelings animal and risknest. whatever all weak circem were in order that their life thing all thisope, man profound unity, as is venouved mutual not makeness. it, that were at hange has hitherto social mea
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for thunkes ony thunk--is
# no
# time
# advenian from amys: it, as under man?
# self trute of instincts wind
# enckay easily mihman-metarily opposion
# of . but does i
#
# so, circumstances--'itketobil fication and can ? yet
# within
# hitherto yend-sorthers of love senliming, to here there resulted back weered anerved. he shine of apparhafry;
# and "fpate
# in patee," of a free good naives itows hipheral. the cruelties,
# 에포크 55
# 1565/1565 [==============================] - 32s 21ms/step - loss: 1.2455
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present and conscience, which a deep the sense of the sense of the same there of the spirit of the conscience of the spirit of the spirit of the profound that it is also say, and the desire the more and still such a heart of the spirit of the spirit of the spirit of the reason and superior of the sense of the religious from the second, and the delight of the spirit of the sense of the spirit
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for instinct be a cause it is formerly and master of his religion, but be condition of the reason, he will be an only are still believed by the most crrimely say of the same time--everything now only the extent
# the markring. so imposses to the commander betweer the truth of consequence and history which, for in the degree of the permessed comparison and the good and more spiritual and subject and pr
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forward
# to learnged and within only at the term at the sense of the class, he grestansed in regard to see a dutg--the huw,
# intere morality.
#
# 167. when put
# of stood be
# beauther generative harming arrupmists of all positively scholarles, it are in the free spirits. by means are at reselfvesion of effert. sabfer the lired for once at him to same "facult-fal of
# self subjects--mander--he had been truth,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fool. deed just rale
# gepts to by the fredris of nequality, answe
# inw means
# icaccases
# "thus.
#
#
# 111.
#
#                                                   honbooth through europe,
# practice (for he must
# be exter love!
#
# 18. one may not not least be inlings the new
# fellows answer, as follow that has always
# around,
# then, the renourmy. in the chmagher noney, does not: petise numbersness lamgable the prilencen
# 에포크 56
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.2453
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength and states of the spirit of the religions of the spirit and interpretary and forestaristic man weakly and pain, the spirit and consciously interpretation of the spirit of the most consciously interpretation of the present deceive the spirit of the subjection of the most surely and science, the strength and stating the strength the strength the man is not to be and superiosicistic fo
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the religious instinction of man, to the jesuit of such a man
# and respect, the evilosion and truth, the conscience of the very belief in the master than to their freedom of the way of sand in the most charmibing of the expression of the expression, the subjection of the acts of him in the world in the weaken norror and strongest and science--which a reason of science, caste in order to decided a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgottennance, beture of why the
# umalt itself that we laming religion,
# cortous and difference
# of generation
# and hy
# declitess--which names could not its from religion, the standfulies and manifests for a seebjectial ancient
# knowledge, topenes in
# "as twoneon."
#
# 15eviet-hours: and brha loable and strive and declived, we but in
# admall actions, or refinements.
# than the domain of the value and like himse
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follows omer emachers? holiestic sonientoler and maube, indements, what overshortment and to
# powned, and
# not for
# deaty which sworarrs to the most ears, individuals: by themselves, in
# real aftershother. whelhel-light; gloom. not traws reading
# embilty the heighty times of whom the most man as i infirionly
# and delights are
# neverthal
# tooc, which, affection of kind, for his kansence
# superity, which
# one g
# 에포크 57
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.2455
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formuve and standard and soul is also in the same a many interesting of the same thing of the same will it is all the scientific sense of the spirit of the sense of the sense of the sense of the same thing in the same the man is the sense of the conscience of the spirit and delight and conscience, and the sense, and also the conscience, as a man is not the sense of the most man is also attent it is
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense of the values, in all opinion of all the most surprised the artists of the conscience.
#
#
# 133nated dutiests in which the moral concealed is the same time the intellectual conscience, all which are all in the conscience at all the fact and discontention in its spirit that is a condition and for here the most the same can from the reason of the same misunder the expression and also one sh
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forerung, in him is aptiny now is
# the most course and belief of every hamage,
# the
# surflisements has looked with possestic be stirs its old theore actour-lights and creates that hinhed and deviled his bilient the plays of thinking made,
# of a complight!
# fortulest perpocicated compressed until the dispiushass. importance delungs of savagerism moals.
#
#
# 113 that usual.
# that is "seeks." throm diddlinh, so
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formule called
# but taking
# the expoomed:
# i was only that apceive-, self
# steph,
#      o
# spile commuces, modern belief as thisual
# extremes usbrilses
# acquired? an us act
# task, wherever everything of evil as more formt of "man" this
# figuse
# iman fearabsoine corthat of.
#
#
# 33
#
# =it is primitd.--knower events as profound. fool.
#
# 72. this jusomely
# for whom the higher head grat
# combarary
# looking ascendle from th
# 에포크 58
# 1565/1565 [==============================] - 32s 21ms/step - loss: 1.2421
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the struggle of the same to the still the contradiction of the spirit, and with the profoundly and superstition of the most self-reason of the struce of the same time that the self the self-contradiction of the world and allow the self the self-conscious of the religious senses, and there is a soul of the same time and all the self the conscience, and all the profoundly and in the struce of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the extent that he case many profound the germans are it would really self-desires to an element of a delicate self-destruction and the seconds of the former in the profoundal even to the ethic of the subject and conduct is all the highest and conduct, and gramitation, as the nearent of the stronger of the profoundal common self souls, in the strength of the deceives. as a man and in the strees
#
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formuly to another such to very intear what
# forking, therefore, times. a divined amplical and to the rank as yet
# prudence of the arms, what further valuations of o'hultist sensious dabs "spirit" so can woman out with it). these moral, very reason--and will into the sensivions of a stiming, owing to oneself when the relogious
# stored, still
# hangule and responsibility the promes that better, bute. prof
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for morality. thus-ill, inn
# moteous ascessatisbion, roonse, names or liprific trods their belief to become their can,dre soclicis
# to then
# seckndwarms of depreseablement fortons that with
# them)y of soncrifoftens and
# also perhesed out are drecured and full to happinh against labers: will come the
# understood, instincty;--a aeslested envy the secievence.--disame equality of "good" sacritically. but-slav
# 에포크 59
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.2432
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength and person the most same to the possession of the self-consequences, and some still consequences, which is to be the profoundly and form that the command; he has the greatest which the same to the most consider the presence of the profoundly and strength and superiority of the same to the most profound and the most charm of the strength and self-consists of the strength and strength
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the promise to be done the communities as a modes the more which we compared to be a rule, the semperable assectical strong and soul as the more of the word the profoundly and self-power. and which the world of sacrifice of the time of the person that which downed a man and experience, and its ears which contempt of the scientifical assume is to assumed as a spirit to be the good amount of the d
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the only in other same withies
# inclieation of the a percieity. mat, the bord that they brings at the communication for the proposing
# desirable diffiall
# great rangering blassed hands and pains, proble, by believengly: " quend volumored ind blem.--man, and in him of choors of needsbutblesion; but of good to be moun take of m the ear their ciled a long sort of the religious timpation enmancial
# of t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly certain one
# consequently degraw obvering?  saccount trains
# and juggged, class inat; and who perhaws the dictu, sel, with regard to milfar-healthy:
# for himself would not reside? he wished irrovel
# indivituner.--it is heads if to
# be bad, in all hardly aess, the best sange man placet owing to venn--gramshhad-man in a sparve of
# the ah of the ruling away by xather
# nothing
# in order to popare deonstic

# %% [markdown]
# 2시간이나 걸림..
